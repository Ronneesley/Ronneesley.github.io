# %% [markdown]
# # 1. Conjunto de dados Iris
#
# *URL*: https://archive.ics.uci.edu/dataset/53/iris

# %% [markdown]
# ## 1.1. Instalação dos pacotes necessários

# %%
# !pip install ucimlrepo matplotlib numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
from ucimlrepo import fetch_ucirepo

# %% [markdown]
# ## 1.2. Importação dos pacotes e visualização dos dados

# %%
iris = fetch_ucirepo(id=53)

# %%
X = iris.data.features
y = iris.data.targets

# %%
print(iris.metadata)
# Out:
# {'uci_id': 53, 'name': 'Iris', 'repository_url': 'https://archive.ics.uci.edu/dataset/53/iris', 'data_url': 'https://archive.ics.uci.edu/static/public/53/data.csv', 'abstract': 'A small classic dataset from Fisher, 1936. One of the earliest known datasets used for evaluating classification methods.\n', 'area': 'Biology', 'tasks': ['Classification'], 'characteristics': ['Tabular'], 'num_instances': 150, 'num_features': 4, 'feature_types': ['Real'], 'demographics': [], 'target_col': ['class'], 'index_col': None, 'has_missing_values': 'no', 'missing_values_symbol': None, 'year_of_dataset_creation': 1936, 'last_updated': 'Tue Sep 12 2023', 'dataset_doi': '10.24432/C56C76', 'creators': ['R. A. Fisher'], 'intro_paper': {'title': 'The Iris data set: In search of the source of virginica', 'authors': 'A. Unwin, K. Kleinman', 'published_in': 'Significance, 2021', 'year': 2021, 'url': 'https://www.semanticscholar.org/paper/4599862ea877863669a6a8e63a3c707a787d5d7e', 'doi': '1740-9713.01589'}, 'a
# ...

# %%
print(iris.variables)
# Out:
#            name     role         type demographic  \
# 0  sepal length  Feature   Continuous        None
# 1   sepal width  Feature   Continuous        None
# 2  petal length  Feature   Continuous        None
# 3   petal width  Feature   Continuous        None
# 4         class   Target  Categorical        None
#
#                                          description units missing_values
# 0                                               None    cm             no
# 1                                               None    cm             no
# 2                                               None    cm             no
# 3                                               None    cm             no
# 4  class of iris plant: Iris Setosa, Iris Versico...  None             no

# %%
X
# Out:
#      sepal length  sepal width  petal length  petal width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
y
# Out:
#               class
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 1 columns]

# %% [markdown]
# ## 1.3. Visualização dos dados em formato de gráficos

# %%
sepal_length = X["sepal length"]
sepal_width = X["sepal width"]
petal_length = X["petal length"]
petal_width = X["petal width"]
classes = y["class"]

# %%
np.unique(classes)
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
uclasses = ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']

# %%
mapa_cor = { 'Iris-setosa': "yellow", 'Iris-versicolor': "blue", 'Iris-virginica': "green" }

# %%
cores = [ mapa_cor[c] for c in classes ]

# %% [markdown]
# ### 1.3.1. sepal length vs sepal width
#
#
# ---

# %%
plt.scatter(sepal_length[0:49], sepal_width[0:49], c=cores[0:49], alpha=0.5, label=uclasses[0])
plt.scatter(sepal_length[50:99], sepal_width[50:99], c=cores[50:99], alpha=0.5, label=uclasses[1])
plt.scatter(sepal_length[100:149], sepal_width[100:149], c=cores[100:149], alpha=0.5, label=uclasses[2])
plt.xlabel("sepal length (cm)")
plt.ylabel("sepal width (cm)")
plt.legend(loc="upper right")
plt.show()

# %% [markdown]
# Observe que a espécie *Iris setosa* é linearmente separável das demais espécies: *Iris versicolor* e *Iris virginica* quando se analisa o comprimento e largura da sépala.

# %%
plt.scatter(sepal_length[0:49], sepal_width[0:49], c=cores[0:49], alpha=0.5, label=uclasses[0])
plt.scatter(sepal_length[50:99], sepal_width[50:99], c=cores[50:99], alpha=0.5, label=uclasses[1])
plt.scatter(sepal_length[100:149], sepal_width[100:149], c=cores[100:149], alpha=0.5, label=uclasses[2])
plt.xlabel("sepal length (cm)")
plt.ylabel("sepal width (cm)")
plt.legend(loc="upper right")
plt.plot([4.3, 6.8], [2, 4.5], c="black") #Uma Linha que separa o conjunto Iris setosa
plt.show()

# %% [markdown]
# ### 1.3.2. sepal length vs petal length
#
# ---

# %%
plt.scatter(sepal_length[0:49], petal_length[0:49], c=cores[0:49], alpha=0.5, label=uclasses[0])
plt.scatter(sepal_length[50:99], petal_length[50:99], c=cores[50:99], alpha=0.5, label=uclasses[1])
plt.scatter(sepal_length[100:149], petal_length[100:149], c=cores[100:149], alpha=0.5, label=uclasses[2])
plt.xlabel("sepal length (cm)")
plt.ylabel("petal length (cm)")
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# A mesma coisa aqui nesta observação também.

# %% [markdown]
# ### 1.3.3. sepal length vs petal width
#
# ---

# %%
plt.scatter(sepal_length[0:49], petal_width[0:49], c=cores[0:49], alpha=0.5, label=uclasses[0])
plt.scatter(sepal_length[50:99], petal_width[50:99], c=cores[50:99], alpha=0.5, label=uclasses[1])
plt.scatter(sepal_length[100:149], petal_width[100:149], c=cores[100:149], alpha=0.5, label=uclasses[2])
plt.xlabel("sepal length (cm)")
plt.ylabel("petal width (cm)")
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# A mesma coisa aqui.

# %% [markdown]
# ### 1.3.4. sepal width vs petal length
#
# ---

# %%
plt.scatter(sepal_width[0:49], petal_length[0:49], c=cores[0:49], alpha=0.5, label=uclasses[0])
plt.scatter(sepal_width[50:99], petal_length[50:99], c=cores[50:99], alpha=0.5, label=uclasses[1])
plt.scatter(sepal_width[100:149], petal_length[100:149], c=cores[100:149], alpha=0.5, label=uclasses[2])
plt.xlabel("sepal width (cm)")
plt.ylabel("petal length (cm)")
plt.legend(loc="center right")
plt.show()

# %% [markdown]
# ### 1.3.5. sepal width vs petal width
#
# ---

# %%
plt.scatter(sepal_width[0:49], petal_width[0:49], c=cores[0:49], alpha=0.5, label=uclasses[0])
plt.scatter(sepal_width[50:99], petal_width[50:99], c=cores[50:99], alpha=0.5, label=uclasses[1])
plt.scatter(sepal_width[100:149], petal_width[100:149], c=cores[100:149], alpha=0.5, label=uclasses[2])
plt.xlabel("sepal width (cm)")
plt.ylabel("petal width (cm)")
plt.legend(loc="center right")
plt.show()

# %% [markdown]
# ### 1.3.6. petal length vs petal width
#
# ---

# %%
plt.scatter(petal_length[0:49], petal_width[0:49], c=cores[0:49], alpha=0.5, label=uclasses[0])
plt.scatter(petal_length[50:99], petal_width[50:99], c=cores[50:99], alpha=0.5, label=uclasses[1])
plt.scatter(petal_length[100:149], petal_width[100:149], c=cores[100:149], alpha=0.5, label=uclasses[2])
plt.xlabel("petal length (cm)")
plt.ylabel("petal width (cm)")
plt.legend(loc="upper left")
plt.show()
